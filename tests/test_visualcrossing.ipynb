# %% [markdown]
# <a href="https://colab.research.google.com/github/Cesc-Fran/meteo/blob/main/tests/test_visualcrossing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Test visual crossing
#
# https://www.visualcrossing.com/resources/documentation/weather-api/timeline-weather-api/
#
#
# revision :
# - author : Fran
# - date.  : 30 july 2025
# - rev    : 10 - first test

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import os
import time

from google.colab import userdata

# %%
# Securely retrieve API key (e.g., from environment variables)
# For Visual Crossing, replace 'YOUR_VISUAL_CROSSING_API_KEY' with your actual key
# It is highly recommended to set this as an environment variable, e.g., VC_API_KEY

# VISUAL_CROSSING_API_KEY = os.getenv('VC_API_KEY', 'YOUR_VISUAL_CROSSING_API_KEY_HERE')

VISUAL_CROSSING_API_KEY = userdata.get('VC_API_KEY')

# %%
# Function to get historical weather data

def fetch_weather_data_vc(city, start_date, end_date, api_key):
    """
    Fetches daily historical weather data from Visual Crossing API.
    Args:
        city (str): Name of the city (e.g., "Madrid, Spain").
        start_date (str): Start date in YYYY-MM-DD format.
        end_date (str): End date in YYYY-MM-DD format.
        api_key (str): Your Visual Crossing API key.
    Returns:
        dict: JSON response from the API, or None if an error occurs.
    """
    base_url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline"
    params = {
        "unitGroup": "metric",
        "contentType": "json",
        "include": "days", # Request daily summaries as specified in documentation [1]
        "key": api_key
    }
    url = f"{base_url}/{city}/{start_date}/{end_date}"

    try:
        response = requests.get(url, params=params)
        response.raise_for_status() # Raise HTTPError for bad responses (4xx or 5xx)
        return response.json()
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred for {city} ({start_date} to {end_date}): {http_err}")
        if response.status_code == 429:
            print("Rate limit exceeded. Consider pausing or increasing your plan.")
        return None
    except requests.exceptions.ConnectionError as conn_err:
        print(f"Connection error occurred for {city} ({start_date} to {end_date}): {conn_err}")
        return None
    except requests.exceptions.Timeout as timeout_err:
        print(f"Timeout error occurred for {city} ({start_date} to {end_date}): {timeout_err}")
        return None
    except requests.exceptions.RequestException as req_err:
        print(f"An unexpected error occurred for {city} ({start_date} to {end_date}): {req_err}")
        return None

# Example usage (will be integrated into the full script below)
# madrid_data = fetch_weather_data_vc("Madrid, Spain", "2023-09-01", "2023-10-31", VISUAL_CROSSING_API_KEY)
# if madrid_data:
#     print(f"Successfully fetched data for Madrid. Days: {len(madrid_data.get('days',))}")

# %%
# test with Montpellier as city

mpl_data = fetch_weather_data_vc("Montpellier, France", "2025-06-15", "2025-07-31", VISUAL_CROSSING_API_KEY)
if mpl_data:
   print(f"Successfully fetched data for Montpellier. Days: {len(mpl_data.get('days',))}")
# Out:
# Successfully fetched data for Montpellier. Days: 47

# %%
mpl_data.keys()
# Out:
# dict_keys(['queryCost', 'latitude', 'longitude', 'resolvedAddress', 'address', 'timezone', 'tzoffset', 'days', 'stations'])

# %%
mpl_data['stations']
# Out:
# {'30003001': {'distance': 27918.0,
#   'latitude': 43.537,
#   'longitude': 4.207,
#   'useCount': 0,
#   'id': '30003001',
#   'name': 'AIGUES-MORTES',
#   'quality': 100,
#   'contribution': 0.0},
#  '34154001': {'distance': 8117.0,
#   'latitude': 43.576,
#   'longitude': 3.965,
#   'useCount': 0,
#   'id': '34154001',
#   'name': 'MONTPELLIER-AEROPORT',
#   'quality': 100,
#   'contribution': 0.0},
#  '34274001': {'distance': 22177.0,
#   'latitude': 43.78,
#   'longitude': 3.729,
#   'useCount': 0,
#   'id': '34274001',
#   'name': 'ST MARTIN DE LONDRES',
#   'quality': 100,
#   'contribution': 0.0},
#  'LFMT': {'distance': 8314.0,
#   'latitude': 43.58,
#   'longitude': 3.97,
#   'useCount': 0,
#   'id': 'LFMT',
#   'name': 'LFMT',
#   'quality': 50,
#   'contribution': 0.0},
#  '34217001': {'distance': 11980.0,
#   'latitude': 43.718,
#   'longitude': 3.867,
#   'useCount': 0,
#   'id': '34217001',
#   'name': 'PRADES LE LEZ',
#   'quality': 100,
#   'contribution': 0.0},
#  '07646099999': {'distance': 46446.0,
#   'latitude': 43.757,
#   'longitude': 4.416,
#   'useCount': 0,
#   'id': '07646099999',
#   'name': 'GARONS, FR',
#   'quality': 99,
#   'contribution': 0.0},
#  '07641099999': {'distance': 27448.0,
#   'latitude': 43.4,
#   'longitude': 3.7,
#   'useCount': 0,
#   'id': '07641099999',
#   'name': 'SETE, FR',
#   'quality': 99,
#   'contribution': 0.0},
#  'D7130': {'distance': 49375.0,
#   'latitude': 43.283,
#   'longitude': 3.465,
#   'useCount': 0,
#   'id': 'D7130',
#   'name': 'DW7130 Agde FR',
#   'quality': 0,
#   'contribution': 0.0},
#  '34301002': {'distance': 28035.0,
#   'latitude': 43.397,
#   'longitude': 3.692,
#   'useCount': 0,
#   'id': '34301002',
#   'name': 'SETE',
#   'quality': 100,
#   'contribution': 0.0},
#  '07643099999': {'distance': 8000.0,
#   'latitude': 43.576,
#   'longitude': 3.963,
#   'useCount': 0,
#   'id': '07643099999',
#   'name': 'MEDITERRANEE, FR',
#   'quality': 99,
#   'contribution': 0.0},
#  'LFTW': {'distance': 46443.0,
#   'latitude': 43.75,
#   'longitude': 4.42,
#   'useCount': 0,
#   'id': 'LFTW',
#   'name': 'LFTW',
#   'quality': 50,
#   'contribution': 0.0},
#  '30352002': {'distance': 26823.0,
#   'latitude': 43.795,
#   'longitude': 4.091,
#   'useCount': 0,
#   'id': '30352002',
#   'name': 'VILLEVIEILLE',
#   'quality': 100,
#   'contribution': 0.0}}

# %%
mpl_df = pd.DataFrame(mpl_data['days'])
mpl_df.head()
# Out:
#      datetime  datetimeEpoch  tempmax  tempmin  temp  feelslikemax  \
# 0  2025-06-15     1749938400     31.0     20.6  25.7          32.8
# 1  2025-06-16     1750024800     30.8     19.4  25.6          29.6
# 2  2025-06-17     1750111200     30.5     18.3  25.0          29.8
# 3  2025-06-18     1750197600     31.6     17.8  25.5          31.4
# 4  2025-06-19     1750284000     30.8     17.9  25.6          31.3
#
#    feelslikemin  feelslike   dew  humidity  ...   sunrise  sunriseEpoch  \
# 0          20.6       26.4  18.5      65.5  ...  06:02:38    1749960158
# 1          19.4       25.3  13.1      48.2  ...  06:02:39    1750046559
# 2          18.3       24.9  13.2      48.9  ...  06:02:43    1750132963
# 3          17.8       25.6  16.3      59.8  ...  06:02:49    1750219369
# 4          17.9       25.9  16.4      58.7  ...  06:02:57    1750305777
#
#      sunset sunsetEpoch  moonphase              conditions  \
# 0  21:27:45  1750015665       0.65  Rain, Partially cloudy
# 1  21:28:08  1750102088       0.68                   Clear
# 2  21:28:29  1750188509       0.72                   Clear
# 3  21:28:48  1750274928       0.75                   Clear
# 4  21:29:05  1750361345       0.79        Partially cloudy
#
#                                          description               icon  \
# 0  Partly cloudy throughout the day with afternoo...               rain
# 1               Clear conditions throughout the day.          clear-day
# 2               Clear conditions throughout the day.          clear-day
# 3               Clear conditions throughout the day.          clear-day
# 4                  Partly cloudy throughout the day.  partly-cloudy-day
#
#                                             stations  source
# 0  [30003001, 34154001, 34274001, 34217001, D7130...     obs
# 1  [30003001, 34154001, 34274001, 34217001, D7130...     obs
# 2  [30003001, 34154001, 34274001, 34217001, D7130...     obs
# 3  [30003001, 34154001, 34274001, 34217001, D7130...     obs
# 4  [30003001, 34154001, 34274001, 34217001, D7130...     obs
#
# [5 rows x 36 columns]

# %%
mpl_df.tail()
# Out:
#       datetime  datetimeEpoch  tempmax  tempmin  temp  feelslikemax  \
# 42  2025-07-27     1753567200     28.2     21.5  25.2          27.6
# 43  2025-07-28     1753653600     28.1     20.1  24.3          27.1
# 44  2025-07-29     1753740000     29.9     19.9  24.9          28.4
# 45  2025-07-30     1753826400     29.4     20.9  25.1          28.2
# 46  2025-07-31     1753912800     30.0     20.6  25.3          28.9
#
#     feelslikemin  feelslike   dew  humidity  ...   sunrise  sunriseEpoch  \
# 42          21.5       25.2  13.1      47.7  ...  06:28:38    1753590518
# 43          20.1       24.1   9.3      39.2  ...  06:29:40    1753676980
# 44          19.9       24.4   7.8      34.8  ...  06:30:42    1753763442
# 45          20.9       24.7  10.9      41.7  ...  06:31:45    1753849905
# 46          20.6       25.1  13.6      49.7  ...  06:32:49    1753936369
#
#       sunset sunsetEpoch  moonphase        conditions  \
# 42  21:12:57  1753643577       0.08  Partially cloudy
# 43  21:11:51  1753729911       0.12  Partially cloudy
# 44  21:10:45  1753816245       0.15  Partially cloudy
# 45  21:09:36  1753902576       0.18  Partially cloudy
# 46  21:08:26  1753988906       0.21  Partially cloudy
#
#                           description               icon  \
# 42  Becoming cloudy in the afternoon.  partly-cloudy-day
# 43  Partly cloudy throughout the day.  partly-cloudy-day
# 44  Becoming cloudy in the afternoon.  partly-cloudy-day
# 45  Becoming cloudy in the afternoon.  partly-cloudy-day
# 46  Partly cloudy throughout the day.  partly-cloudy-day
#
#                                              stations  source
# 42  [30003001, 34154001, 34274001, 34217001, D7130...     obs
# 43  [30003001, 34154001, 34274001, LFMT, 34217001,...     obs
# 44                                [LFMT, D7130, LFTW]     obs
# 45                                [LFMT, D7130, LFTW]    comb
# 46                                               None    fcst
#
# [5 rows x 36 columns]

# %%
mpl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 36 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   datetime        47 non-null     object
#  1   datetimeEpoch   47 non-null     int64
#  2   tempmax         47 non-null     float64
#  3   tempmin         47 non-null     float64
#  4   temp            47 non-null     float64
#  5   feelslikemax    47 non-null     float64
#  6   feelslikemin    47 non-null     float64
#  7   feelslike       47 non-null     float64
#  8   dew             47 non-null     float64
#  9   humidity        47 non-null     float64
#  10  precip          47 non-null     float64
#  11  precipprob      47 non-null     float64
#  12  precipcover     47 non-null     float64
#  13  preciptype      17 non-null     object
#  14  snow            47 non-null     float64
#  15  snowdepth       47 non-null     float64
#  16  windgust        47 non-null     float64
#  17  windspeed       47 non-null     float64
#  18  winddir         47 non-null     float64
#  19  pressure        47 non-null     float64
#  20  cloudcover      47 non-null     float64
#  21  visibility      47 non-null     float64
#  22  solarradiation  47 non-null     float64
#  23  solarenergy     47 non-null     float64
#  24  uvindex         47 non-null     float64
#  25  severerisk      47 non-null     float64
#  26  sunrise         47 non-null     object
#  27  sunriseEpoch    47 non-null     int64
#  28  sunset          47 non-null     object
#  29  sunsetEpoch     47 non-null     int64
#  30  moonphase       47 non-null     float64
#  31  conditions      47 non-null     object
#  32  description     47 non-null     object
#  33  icon            47 non-null     object
#  34  stations        46 non-null     object
#  35  source          47 non-null     object
# dtypes: float64(24), int64(3), object(9)
# memory usage: 13.3+ KB

# %%
mpl_df.loc[0, 'stations']
# Out:
# ['30003001',
#  '34154001',
#  '34274001',
#  '34217001',
#  'D7130',
#  '07643099999',
#  '30352002']

# %%
stations_df = mpl_df.loc[0:45,'stations'].map(lambda x: len(x))
stations_df
# Out:
# 0     [30003001, 34154001, 34274001, 34217001, D7130...
# 1     [30003001, 34154001, 34274001, 34217001, D7130...
# 2     [30003001, 34154001, 34274001, 34217001, D7130...
# 3     [30003001, 34154001, 34274001, 34217001, D7130...
# 4     [30003001, 34154001, 34274001, 34217001, D7130...
# 5     [30003001, 34154001, 34274001, 34217001, D7130...
# 6     [30003001, 34154001, 34274001, 34217001, D7130...
# 7     [30003001, 34154001, 34274001, 34217001, D7130...
# 8     [30003001, 34154001, 34274001, 34217001, D7130...
# 9     [30003001, 34154001, 34274001, 34217001, D7130...
# 10    [30003001, 34154001, 34274001, 34217001, D7130...
# 11    [30003001, 34154001, 34274001, 34217001, D7130...
# 12    [30003001, 34154001, 34274001, 34217001, D7130...
# 13    [30003001, 34154001, 34274001, 34217001, D7130...
# 14    [30003001, 34154001, 34274001, 34217001, D7130...
# 15    [30003001, 34154001, 34274001, 34217001, D7130...
# 16    [30003001, 34154001, 34274001, 34217001, D7130...
# 17    [30003001, 34154001, 34274001, 34217001, D7130...
# 18    [30003001, 34154001, 34274001, 34217001, D7130...
# 19    [30003001, 34154001, 34274001, 34217001, 07641...
# 20    [30003001, 34154001, 34274001, 34217001, D7130...
# 21    [30003001, 34154001, 34274001, 34217001, D7130...
# 22    [30003001, 34154001, 34274001, 34217001, D7130...
# 23    [30003001, 34154001, 34274001, LFMT, 34217001,...
# 24    [30003001, LFMT, 34154001, 34274001, 34217001,...
# 25    [30003001, 34154001, 34274001, 34217001, D7130...
# 26    [30003001, 34154001, 34274001, 34217001, D7130...
# 27    [30003001, 34154001, 34274001, 34217001, D7130...
# 28    [30003001, 34154001, 34274001, 34217001, D7130...
# 29    [30003001, 34154001, 34274001, 34217001, D7130...
# 30    [30003001, 34154001, 34274001, 34217001, D7130...
# 31    [30003001, 34154001, 34274001, 34217001, D7130...
# 32    [30003001, 34154001, 34274001, 34217001, D7130...
# 33    [30003001, 34154001, 34274001, 34217001, D7130...
# 34    [30003001, 34154001, 34274001, 34217001, D7130...
# 35    [30003001, 34154001, 34274001, 34217001, D7130...
# 36    [30003001, 34154001, 34274001, 34217001, D7130...
# 37    [30003001, 34154001, 34274001, 34217001, D7130...
# 38    [30003001, 34154001, 34274001, 34217001, D7130...
# 39    [30003001, 34154001, 34274001, 34217001, D7130...
# 40    [30003001, 34154001, 34274001, 34217001, D7130...
# 41    [30003001, 34154001, 34274001, 34217001, D7130...
# 42    [30003001, 34154001, 34274001, 34217001, D7130...
# 43    [30003001, 34154001, 34274001, LFMT, 34217001,...
# 44                                  [LFMT, D7130, LFTW]
# 45                                  [LFMT, D7130, LFTW]
# Name: stations, dtype: object

# %%
mpl_df.loc[0:45,'stations'].map(lambda x: len(x))
# Out:
# 0      7
# 1      8
# 2      7
# 3      7
# 4      7
# 5      7
# 6      8
# 7      7
# 8      8
# 9      7
# 10     7
# 11     8
# 12     7
# 13     7
# 14     7
# 15     8
# 16     7
# 17     8
# 18     8
# 19     8
# 20     7
# 21     7
# 22     7
# 23    10
# 24    10
# 25     7
# 26     7
# 27     7
# 28     7
# 29     8
# 30     7
# 31     7
# 32     7
# 33     7
# 34     8
# 35     7
# 36     8
# 37     7
# 38     7
# 39     8
# 40     7
# 41     7
# 42     7
# 43     9
# 44     3
# 45     3
# Name: stations, dtype: int64
